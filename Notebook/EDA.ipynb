# %% [markdown]
# # Import library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Gathering

# %%
df=pd.read_csv(r"/Users/rahuldhakad/Desktop/Acadamic_Risk_Project/project_minor/Data/student_academic_risk_dataset_5000.csv")
df.head(1)
# Out:
#    Student_ID  Age Gender  Attendance_Percentage  Previous_Grade  \
# 0        1000   21   Male                   85.1            39.9
#
#    Current_Grade  Assignments_Submitted  Behavior_Score Parent_Education  \
# 0           65.5                      9               3         Graduate
#
#   Family_Income Internet_Access  Study_Hours  Academic_Risk
# 0           Low             Yes          1.6              0

# %% [markdown]
# # Basic infomation of data

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Attendance_Percentage',
#        'Previous_Grade', 'Current_Grade', 'Assignments_Submitted',
#        'Behavior_Score', 'Parent_Education', 'Family_Income',
#        'Internet_Access', 'Study_Hours', 'Academic_Risk'],
#       dtype='object')

# %%
# checking information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             5000 non-null   int64
#  1   Age                    5000 non-null   int64
#  2   Gender                 5000 non-null   object
#  3   Attendance_Percentage  5000 non-null   float64
#  4   Previous_Grade         5000 non-null   float64
#  5   Current_Grade          5000 non-null   float64
#  6   Assignments_Submitted  5000 non-null   int64
#  7   Behavior_Score         5000 non-null   int64
#  8   Parent_Education       3720 non-null   object
#  9   Family_Income          5000 non-null   object
#  10  Internet_Access        5000 non-null   object
#  11  Study_Hours            5000 non-null   float64
#  12  Academic_Risk          5000 non-null   int64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 507.9+ KB

# %%
# 1 - acedemic risk
# 0 - academic safe

# %%
# we can see in our data have some object(columns or values) so we want to convert that in numeric value

# %% [markdown]
# # check missing values

# %%
df.isnull().sum()
# Out:
# Student_ID                  0
# Age                         0
# Gender                      0
# Attendance_Percentage       0
# Previous_Grade              0
# Current_Grade               0
# Assignments_Submitted       0
# Behavior_Score              0
# Parent_Education         1280
# Family_Income               0
# Internet_Access             0
# Study_Hours                 0
# Academic_Risk               0
# dtype: int64

# %%
# here in Parent_Education column we seen null values in 1280 null values

# %% [markdown]
# # check duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# we dont have any duplicate values

# %% [markdown]
# # EDA

# %% [markdown]
# ### descriptive statistic

# %%
df.describe()
# Out:
#         Student_ID          Age  Attendance_Percentage  Previous_Grade  \
# count  5000.000000  5000.000000            5000.000000     5000.000000
# mean   3499.500000    17.985400              77.763060       64.912900
# std    1443.520003     1.990874              11.659233       14.798028
# min    1000.000000    15.000000              40.000000       30.000000
# 25%    2249.750000    16.000000              69.800000       54.400000
# 50%    3499.500000    18.000000              78.000000       64.900000
# 75%    4749.250000    20.000000              86.000000       74.925000
# max    5999.000000    21.000000             100.000000      100.000000
#
#        Current_Grade  Assignments_Submitted  Behavior_Score  Study_Hours  \
# count    5000.000000            5000.000000     5000.000000   5000.00000
# mean       62.858400               4.610400        2.996000      3.01406
# std        16.228852               2.858644        1.409816      1.46590
# ...

# %% [markdown]
# ##### univariate analysis

# %%
# we check attendence distribution

sns.histplot(data=df, x = 'Attendance_Percentage')
plt.title("Attendance Distribution")
plt.show()

# %%
# mostly attendance is between 70 to 90

# %%
# we check currect grade 

sns.histplot(data=df, x = 'Current_Grade')
plt.title("Currect_Grade Distribution")
plt.show()

# %%
# current grade data is normally distributed

# %%
# we check study hour distribution  

sns.histplot(data=df, x = 'Study_Hours')
plt.title("Study_Hours Distribution")
plt.show()

# %%
# Stduy Hour coloumn also normally distributed

# %%
#Gender Distribution
sns.countplot(data=df, x = 'Gender')
plt.title("Gender  Distribution")
plt.show()

# %%
# Gender column is balanced

# %%
#Parent_Education

# %%
sns.countplot(data=df, x = 'Parent_Education')
plt.title("Parent_Education Distribution")
plt.show()

# %%
sns.countplot(data=df, x = 'Academic_Risk')
plt.title("Parent_Education Distribution")
plt.show()

# %% [markdown]
# ## bivariate analysis

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Attendance_Percentage',
#        'Previous_Grade', 'Current_Grade', 'Assignments_Submitted',
#        'Behavior_Score', 'Parent_Education', 'Family_Income',
#        'Internet_Access', 'Study_Hours', 'Academic_Risk'],
#       dtype='object')

# %%
# Academic_Risk vs attendence

sns.boxplot(data = df, x ="Academic_Risk", y="Attendance_Percentage")
plt.show()

# %%
# based on attendece Acadimic_Risk is high

# %%
# Academic_Risk vs Current_Grade

sns.boxplot(data = df, x ="Academic_Risk", y="Current_Grade")
plt.show()

# %%
# based on  Current_Grade acadimic Risk also is high

# %%
# Academic_Risk vs Family_Income

sns.boxplot(data = df, x ="Academic_Risk", y="Family_Income")
plt.show()

# %%
# we dont see have any acadimic risk based on family income

# %%
# Academic_Risk vs Internet_Access

sns.countplot(data = df, hue ="Academic_Risk", x="Internet_Access")
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
num_df = df.select_dtypes(include = 'int')
corr = num_df.corr()

# %%
sns.heatmap(corr, annot = True)
plt.show()

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Attendance_Percentage',
#        'Previous_Grade', 'Current_Grade', 'Assignments_Submitted',
#        'Behavior_Score', 'Parent_Education', 'Family_Income',
#        'Internet_Access', 'Study_Hours', 'Academic_Risk'],
#       dtype='object')

# %%
sns.countplot(data =df , x='Family_Income', hue= 'Internet_Access', )
plt.show()

# %%
sns.countplot(data =df , x='Age', hue= 'Internet_Access', )
plt.show()

# %% [markdown]
# # insights

# %%
After EDA we will have some insight
1. Low attendence  --- higher dropout risk
2. low study hours  -- poor performance
3. Low income + no internet -- high risk

# %% [markdown]
# ## training code

# %%
# ==============================
# 1. Import Libraries
# ==============================

import pandas as pd
import numpy as np
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# ==============================
# 2. Load Dataset
# ==============================

df = pd.read_csv("/Users/rahuldhakad/Desktop/Acadamic_Risk_Project/project_minor/Data/student_academic_risk_dataset_5000.csv")

print("Dataset Shape:", df.shape)


# ==============================
# 3. Data Cleaning
# ==============================

# remove duplicates
df = df.drop_duplicates()

# check missing values
print(df.isnull().sum())


# ==============================
# 4. Encode Categorical Variables
# ==============================

le = LabelEncoder()

categorical_cols = [
    "Gender",
    "Parent_Education",
    "Family_Income",
    "Internet_Access"
]

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])


# ==============================
# 5. Define Features and Target
# ==============================

X = df.drop(["Student_ID", "Academic_Risk"], axis=1)

y = df["Academic_Risk"]


# ==============================
# 6. Feature Scaling
# ==============================

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)


# ==============================
# 7. Train Test Split
# ==============================

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print("Training Data:", X_train.shape)
print("Testing Data:", X_test.shape)


# ==============================
# 8. Train Logistic Regression Model
# ==============================

model = LogisticRegression()

model.fit(X_train, y_train)


# ==============================
# 9. Model Prediction
# ==============================

y_pred = model.predict(X_test)


# ==============================
# 10. Model Evaluation
# ==============================

print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# Dataset Shape: (5000, 13)
# Student_ID                  0
# Age                         0
# Gender                      0
# Attendance_Percentage       0
# Previous_Grade              0
# Current_Grade               0
# Assignments_Submitted       0
# Behavior_Score              0
# Parent_Education         1280
# Family_Income               0
# Internet_Access             0
# Study_Hours                 0
# Academic_Risk               0
# dtype: int64
# Training Data: (4000, 11)
# Testing Data: (1000, 11)
# Accuracy: 0.769
#
# Confusion Matrix
# [[320 117]
#  [114 449]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       437
#            1       0.79      0.80      0.80       563
#
#     accuracy                           0.77      1000
#    macro avg       0.77      0.76      0.77      1000
# weighted avg       0.77      0.77      0.77      1000
